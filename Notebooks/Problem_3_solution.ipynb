# %% [markdown]
# # Open problem: 3
#
# Try to create a small catalogue of the sources in this field. Run a source detection, and for each significant source, perform a 3D analysis. List your results!
# Open a catalogue of known gamma-ray sources and, when possible, associate the analyzed sources.

# %%
import matplotlib.pyplot as plt

from pathlib import Path
import numpy as np
from astropy.table import Table
import astropy.units as u
from astropy.coordinates import SkyCoord
from regions import CircleSkyRegion

from gammapy.catalog import SourceCatalogGammaCat
from gammapy.datasets import MapDataset, Datasets
from gammapy.data import (
    DataStore,
    Observation,
    Observations,
)
from gammapy.estimators import ExcessMapEstimator, TSMapEstimator
from gammapy.estimators.utils import find_peaks, find_peaks_in_flux_map
from gammapy.makers import (
    MapDatasetMaker, 
    SafeMaskMaker, 
    FoVBackgroundMaker
)
from gammapy.maps import MapAxis, WcsGeom
from gammapy.modeling import Fit
from gammapy.modeling.models import (
    ExpCutoffPowerLawSpectralModel,
    FoVBackgroundModel,
    GaussianSpatialModel,
    PointSpatialModel,
    PowerLawSpectralModel,
    SkyModel,
    Model,
    Models,
)

# %%
# to silence the warnings
import warnings
warnings.filterwarnings('ignore', category=RuntimeWarning, append=True)

# %%
# if neede, set the path of the IRF:
# %env CALDB=../caldb/

# %%
data_store = DataStore.from_dir("../CTA-SDC")

# %%
#source coordinates
l, b = 341.90669676 * u.deg, -3.62457011 * u.deg 
pointing = SkyCoord(l, b, frame="galactic")

# %%
selection = dict(
    type="sky_circle",
    frame="galactic",
    lon=pointing.galactic.l.deg,
    lat=pointing.galactic.b.deg,
    radius="5 deg",
)
selected_obs_table = data_store.obs_table.select_observations(selection)

# %%
observations = data_store.get_observations(selected_obs_table["OBS_ID"])
len(observations)
# Out:
# 37

# %%
print(observations[0])
# Out:
# Observation
#
# 	obs id            : 5000002225
#  	tstart            : 61884.22
# 	tstop             : 61884.24
# 	duration          : 1575.00 s
# 	pointing (icrs)   : 255.2 deg, -43.8 deg
#
# 	deadtime fraction : 0.0%

# %% [markdown]
# Now, we generate the 'stacked' dataset:

# %%
# Reduced IRFs are defined in true energy (i.e. not measured energy).
energy_axis_true = MapAxis.from_energy_bounds(
    0.001, 40, 10, unit="TeV", name="energy_true"
)

energy_axis = MapAxis.from_energy_bounds(0.012, 100.0, 8, unit="TeV")

geom = WcsGeom.create(
    skydir=(pointing.galactic.l.deg , pointing.galactic.b.deg),
    binsz=0.01,
    width=(5, 5),
    frame="galactic",
    proj="CAR",
    axes=[energy_axis],
)

# %%
stacked = MapDataset.create(
    geom=geom, energy_axis_true=energy_axis_true, name="my-dataset"
)

# %%
offset_max = 5 * u.deg
maker = MapDatasetMaker()
maker_safe_mask = SafeMaskMaker(
    methods=["offset-max", "aeff-max"], aeff_percent=10, offset_max=offset_max
)

maker_fov = FoVBackgroundMaker(method="fit")

# %%
for i, obs in enumerate(observations):
    # First a cutout of the target map is produced
    cutout = stacked.cutout(
        obs.get_pointing_icrs(obs.tmid), width=2 * offset_max, name=f"obs-{obs.obs_id}"
    )
    # A MapDataset is filled in this cutout geometry
    dataset = maker.run(cutout, obs)
    # The data quality cut is applied
    dataset = maker_safe_mask.run(dataset, obs)
    # fit background model
    dataset = maker_fov.run(dataset)
    print(
        f"{i} of {len(observations)}, Background norm obs {obs.obs_id}: {dataset.background_model.spectral_model.norm.value:.2f}"
    )
    # The resulting dataset cutout is stacked onto the final one
    stacked.stack(dataset)

print(stacked)
# Out:
# 0 of 37, Background norm obs 5000002225: 1.23
# 1 of 37, Background norm obs 5000002226: 1.24
# 2 of 37, Background norm obs 5000002250: 1.12
# 3 of 37, Background norm obs 5000002251: 1.16
# 4 of 37, Background norm obs 5000002280: 1.23
# 5 of 37, Background norm obs 5000002307: 1.19
# 6 of 37, Background norm obs 5000002308: 1.52
# 7 of 37, Background norm obs 5000002404: 1.14
# 8 of 37, Background norm obs 5000002405: 1.10
# 9 of 37, Background norm obs 5000002436: 1.29
# 10 of 37, Background norm obs 5000002437: 1.32
# 11 of 37, Background norm obs 5000002459: 1.14
# 12 of 37, Background norm obs 5000002461: 1.37
# 13 of 37, Background norm obs 5000002635: 1.25
# 14 of 37, Background norm obs 5000002636: 1.24
# 15 of 37, Background norm obs 5000002652: 1.15
# 16 of 37, Background norm obs 5000002653: 1.15
# 17 of 37, Background norm obs 5000002666: 1.16
# 18 of 37, Background norm obs 5000002667: 2.48
# 19 of 37, Background norm obs 5000002723: 1.25
# 20 of 37, Background norm obs 5000002831: 1.22
# 21 of 37, Background norm obs 5000002833: 1.47
# 22 of 37, Background norm obs 5000002886: 1.20
# 23 of 37, Background norm obs 5000002932: 1.49
# 24 of 37, Background norm obs 5000002959: 1.24
# 25 of 37, Background norm obs 5000002961: 1.17
# 26 of 37, Background norm obs 5000002964: 1.31
# 27 of 37, Background norm obs 5000003155: 1.13
# 28 of 37, Background norm obs 5000003156: 1.20
# 29 of 37, Background norm obs 5000003164: 1.21
# 30 of 37, Background norm obs 5000003165: 1.55
# 31 of 37, Background norm obs 5000003184: 1.59
# 32 of 37, Background norm obs 5000003270: 1.30
# 33 of 37, Background norm obs 5000003287: 1.26
# 34 of 37, Background norm obs 5000003288: 1.20
# 35 of 37, Background norm obs 5000003346: 1.21
# 36 of 37, Background norm obs 5000003348: 1.18
# MapDataset
# ----------
#
#   Name                            : my-dataset
#
#   Total counts                    : 31578
#   Total background counts         : 31577.55
#   Total excess counts             : 0.45
#
#   Predicted counts                : 31577.56
#   Predicted background counts     : 31577.55
#   Predicted excess counts         : nan
#
#   Exposure min                    : 2.87e-06 m2 s
#   Exposure max                    : 1.01e+11 m2 s
#
#   Number of total bins            : 2000000
#   Number of fit bins              : 1206979
#
#   Fit statistic type              : cash
#   Fit statistic value (-2 log(L)) : nan
#
#   Number of models                : 0
#   Number of parameters            : 0
#   Number of free parameters       : 0

# %% [markdown]
# Let's inspect the field:

# %%
excess = stacked.excess.sum_over_axes()
excess.smooth("0.06 deg").plot(stretch="sqrt", add_cbar=True)
plt.show()

# %%
spatial_model = PointSpatialModel()

# We choose units consistent with the map units here...
spectral_model = PowerLawSpectralModel(amplitude="1e-12 cm-2 s-1 TeV-1", index=2)
model = SkyModel(spatial_model=spatial_model, spectral_model=spectral_model)

# %%
estimator = TSMapEstimator(
    model,
    kernel_width="0.5 deg",
    energy_edges=[0.03, 50] * u.TeV,
)
maps = estimator.run(stacked)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(
    ncols=3,
    figsize=(20, 3),
    subplot_kw={"projection": stacked.counts.geom.wcs},
    gridspec_kw={"left": 0.1, "right": 0.98},
)

maps["sqrt_ts"].plot(ax=ax1, add_cbar=True)
ax1.set_title("Significance map")
maps["flux"].plot(ax=ax2, add_cbar=True, stretch="sqrt", vmin=0)
ax2.set_title("Flux map")
maps["niter"].plot(ax=ax3, add_cbar=True)
ax3.set_title("Iteration map")
plt.show()

# %%
sources = find_peaks(maps["sqrt_ts"], threshold=5, min_distance="0.15 deg")
nsou = len(sources)
display(sources)

# Plot sources on top of significance sky image
plt.figure(figsize=(9, 5))
ax = maps["sqrt_ts"].plot(add_cbar=True)

ax.scatter(
    sources["ra"],
    sources["dec"],
    transform=ax.get_transform("icrs"),
    color="none",
    edgecolor="w",
    marker="o",
    s=600,
    lw=1.5,
)
plt.show()

# sphinx_gallery_thumbnail_number = 3
# Out:
# <Table length=8>
#  value    x     y       ra       dec
#                        deg       deg
# float64 int64 int64  float64   float64
# ------- ----- ----- --------- ---------
#  13.345   481   313 254.71547 -47.45615
#  12.962    24   295 258.84397 -43.90530
#  9.7698   316   304 256.29637 -46.20685
#  8.3772   128   385 256.98008 -44.21748
#  8.1873   138   365 257.12111 -44.41701
#  7.2059   159   381 256.76563 -44.48976
#  6.9839   302   327 256.15446 -45.95623
#  5.6959   358   409 254.72962 -45.89609

# %% [markdown]
# Let's repeat the analysis by creating an exclusion mask:

# %%
exclusion_src1 = CircleSkyRegion(
    center=SkyCoord(344.1646678, -3.16256952, unit="deg", frame="galactic"),
    radius=0.2 * u.deg,
)
exclusion_src2 = CircleSkyRegion(
    center=SkyCoord(343.05454002, -2.46546336, unit="deg", frame="galactic"),
    radius=0.7 * u.deg,
)
exclusion_src3 = CircleSkyRegion(
    center=SkyCoord(341.17287207, -3.14538304, unit="deg", frame="galactic"),
    radius=0.2 * u.deg,
)
exclusion_src4 = CircleSkyRegion(
    center=SkyCoord(341.38004212, -2.86952312, unit="deg", frame="galactic"),
    radius=0.2 * u.deg,
)
exclusion_src5 = CircleSkyRegion(
    center=SkyCoord(340.82287577, -2.01295808, unit="deg", frame="galactic"),
    radius=0.2 * u.deg,
)
exclusion_src6 = CircleSkyRegion(
    center=SkyCoord(339.58634079, -3.01718097, unit="deg", frame="galactic"),
    radius=0.2 * u.deg,
)

exclusion_geom = geom.to_image()

exclusion_mask = ~exclusion_geom.region_mask([exclusion_src1, exclusion_src2, exclusion_src3,
                                   exclusion_src4, exclusion_src5, exclusion_src6])
exclusion_mask.plot()
plt.show()

# %%
maker_fov = FoVBackgroundMaker(method="fit", exclusion_mask=exclusion_mask)

for i, obs in enumerate(observations):
    # First a cutout of the target map is produced
    cutout = stacked.cutout(
        obs.get_pointing_icrs(obs.tmid), width=2 * offset_max, name=f"obs-{obs.obs_id}"
    )
    # A MapDataset is filled in this cutout geometry
    dataset = maker.run(cutout, obs)
    # The data quality cut is applied
    dataset = maker_safe_mask.run(dataset, obs)
    # fit background model
    dataset = maker_fov.run(dataset)
    print(
        f"{i} of {len(observations)}, Background norm obs {obs.obs_id}: {dataset.background_model.spectral_model.norm.value:.2f}"
    )
    # The resulting dataset cutout is stacked onto the final one
    stacked.stack(dataset)

print(stacked)
# Out:
# 0 of 37, Background norm obs 5000002225: 1.16
# 1 of 37, Background norm obs 5000002226: 1.19
# 2 of 37, Background norm obs 5000002250: 1.07
# 3 of 37, Background norm obs 5000002251: 1.08
# 4 of 37, Background norm obs 5000002280: 1.07
# 5 of 37, Background norm obs 5000002307: 1.06
# 6 of 37, Background norm obs 5000002308: 1.31
# 7 of 37, Background norm obs 5000002404: 1.07
# 8 of 37, Background norm obs 5000002405: 1.09
# 9 of 37, Background norm obs 5000002436: 1.03
# 10 of 37, Background norm obs 5000002437: 1.05
# 11 of 37, Background norm obs 5000002459: 1.01
# 12 of 37, Background norm obs 5000002461: 1.02
# 13 of 37, Background norm obs 5000002635: 1.14
# 14 of 37, Background norm obs 5000002636: 1.38
# 15 of 37, Background norm obs 5000002652: 1.09
# 16 of 37, Background norm obs 5000002653: 1.08
# 17 of 37, Background norm obs 5000002666: 1.04
# 18 of 37, Background norm obs 5000002667: 1.83
# 19 of 37, Background norm obs 5000002723: 1.03
# 20 of 37, Background norm obs 5000002831: 1.05
# 21 of 37, Background norm obs 5000002833: 1.22
# 22 of 37, Background norm obs 5000002886: 0.99
# 23 of 37, Background norm obs 5000002932: 1.31
# 24 of 37, Background norm obs 5000002959: 1.02
# 25 of 37, Background norm obs 5000002961: 0.91
# 26 of 37, Background norm obs 5000002964: 1.13
# 27 of 37, Background norm obs 5000003155: 0.98
# 28 of 37, Background norm obs 5000003156: 1.08
# 29 of 37, Background norm obs 5000003164: 1.08
# 30 of 37, Background norm obs 5000003165: 1.31
# 31 of 37, Background norm obs 5000003184: 1.32
# 32 of 37, Background norm obs 5000003270: 1.11
# 33 of 37, Background norm obs 5000003287: 1.04
# 34 of 37, Background norm obs 5000003288: 0.97
# 35 of 37, Background norm obs 5000003346: 1.08
# 36 of 37, Background norm obs 5000003348: 1.05
# MapDataset
# ----------
#
#   Name                            : my-dataset
#
#   Total counts                    : 63156
#   Total background counts         : 60370.61
#   Total excess counts             : 2785.39
#
#   Predicted counts                : 60370.62
#   Predicted background counts     : 60370.61
#   Predicted excess counts         : nan
#
#   Exposure min                    : 5.74e-06 m2 s
#   Exposure max                    : 2.03e+11 m2 s
#
#   Number of total bins            : 2000000
#   Number of fit bins              : 1206979
#
#   Fit statistic type              : cash
#   Fit statistic value (-2 log(L)) : nan
#
#   Number of models                : 0
#   Number of parameters            : 0
#   Number of free parameters       : 0

# %% [markdown]
# And now let's fit each source with a model:

# %%
bkg_model = FoVBackgroundModel(dataset_name=stacked.name)
bkg_model.spectral_model.norm.value = 1.0
    
models_stacked = Models([bkg_model])

# %%
for i, src in enumerate(sources):
    print(f"- Analysis of the source {i+1}...")

    spectral_model = PowerLawSpectralModel(
    index=2,
    amplitude=1e-12 * u.Unit("cm-2 s-1 TeV-1"),
    reference=1.0 * u.TeV,
            )
    
    spatial_model = GaussianSpatialModel(
    lon_0=src["ra"] * u.deg, lat_0=src["dec"] * u.deg, frame="icrs",
    sigma="0.1 deg"
            )

    model = SkyModel(
        spatial_model=spatial_model,
        spectral_model=spectral_model,
        name=f"src_{i}",
            )

    models_stacked.extend(Models([model]))
    
    stacked.models = models_stacked

    stacked.models[-1].parameters["lon_0"].frozen = True
    stacked.models[-1].parameters["lat_0"].frozen = True

    fit = Fit(optimize_opts={"print_level": 1})
    result = fit.run(datasets=[stacked])
    print(result)
    print(f"   * Analysis of the source {i+1}... complete!")

#    for n in stacked.models[-1].parameters.names:
#        stacked.models[-1].parameters[n].frozen = True
# Out:
# - Analysis of the source 1...
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 138
# 	total stat : 427707.78
#
# CovarianceResult
#
# 	backend    : minuit
# 	method     : hesse
# 	success    : True
# 	message    : Hesse terminated successfully.
#
#    * Analysis of the source 1... complete!
# - Analysis of the source 2...
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Machine accuracy limits further improvement
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00271645 is smaller than machine limit 0.0254714 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00271645 is above tolerance 0.002
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.000312427 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 6 ] = -0.0017549
# W MnPosDef Added to diagonal of Error matrix a value 0.501756
# W VariableMetricBuilder gdel = -0.141537
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Machine accuracy limits further improvement
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000228849 is smaller than machine limit 0.0254714 while 0.0002 was requested
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 396
# 	total stat : 427338.54
#
# CovarianceResult
#
# 	backend    : minuit
# 	method     : hesse
# 	success    : True
# 	message    : Hesse terminated successfully.
#
#    * Analysis of the source 2... complete!
# - Analysis of the source 3...
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 658
# 	total stat : 425743.87
#
# CovarianceResult
#
# 	backend    : minuit
# 	method     : hesse
# 	success    : True
# 	message    : Hesse terminated successfully.
#
#    * Analysis of the source 3... complete!
# - Analysis of the source 4...
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Machine accuracy limits further improvement
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000270306 is smaller than machine limit 0.0252571 while 0.0002 was requested
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 923
# 	total stat : 423743.42
#
# CovarianceResult
#
# 	backend    : minuit
# 	method     : hesse
# 	success    : True
# 	message    : Hesse terminated successfully.
#
#    * Analysis of the source 4... complete!
# - Analysis of the source 5...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00158181 is smaller than machine limit 0.0252472 while 0.0002 was requested
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 792
# 	total stat : 423578.02
#
# CovarianceResult
#
# 	backend    : minuit
# 	method     : hesse
# 	success    : True
# 	message    : Hesse terminated successfully.
#
#    * Analysis of the source 5... complete!
# - Analysis of the source 6...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00343057 is smaller than machine limit 0.0252471 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00343057 is above tolerance 0.002
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00231249 is smaller than machine limit 0.0252471 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00231249 is above tolerance 0.002
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Machine accuracy limits further improvement
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 1530
# 	total stat : 423576.21
#
# CovarianceResult
#
# 	backend    : minuit
# 	method     : hesse
# 	success    : True
# 	message    : Hesse terminated successfully.
#
#    * Analysis of the source 6... complete!
# - Analysis of the source 7...
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.0265639 > 0
# W MnPosDef non-positive diagonal element in covariance matrix[ 10 ] = -0.000311097
# W MnPosDef non-positive diagonal element in covariance matrix[ 14 ] = -0.000408026
# W MnPosDef non-positive diagonal element in covariance matrix[ 16 ] = -0.0034771
# W MnPosDef non-positive diagonal element in covariance matrix[ 17 ] = -0.00258705
# W MnPosDef non-positive diagonal element in covariance matrix[ 18 ] = -0.00780379
# W MnPosDef Added to diagonal of Error matrix a value 0.507805
# W VariableMetricBuilder gdel = -1.26472
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# W VariableMetricBuilder Matrix not pos.def, gdel = 0.0228676 > 0
# W MnPosDef Matrix forced pos-def by adding to diagonal 0.563588
# W VariableMetricBuilder gdel = -0.146317
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Machine accuracy limits further improvement
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Iterations finish without convergence; Edm 59529.2 Requested 0.0002
# W VariableMetricBuilder FunctionMinimum is invalid after second try
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Machine accuracy limits further improvement
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Iterations finish without convergence; Edm 871039 Requested 0.0002
# W VariableMetricBuilder FunctionMinimum is invalid after second try
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Iterations finish without convergence; Edm 0.0578115 Requested 0.0002
# W VariableMetricBuilder No convergence; Edm 0.0578115 is above tolerance 0.002
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Iterations finish without convergence; Edm 0.0578115 Requested 0.0002
# W VariableMetricBuilder No convergence; Edm 0.0578115 is above tolerance 0.002
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Iterations finish without convergence; Edm 0.0578115 Requested 0.0002
# W VariableMetricBuilder No convergence; Edm 0.0578115 is above tolerance 0.002
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : False
# 	message    : Optimization failed. Estimated distance to minimum too large.
# 	nfev       : 4182
# 	total stat : 423471.36
#
# CovarianceResult
#
# 	backend    : minuit
# 	method     : hesse
# 	success    : True
# 	message    : Hesse terminated successfully.
#
#    * Analysis of the source 7... complete!
# - Analysis of the source 8...
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.00785812 is smaller than machine limit 0.02524 while 0.0002 was requested
# W VariableMetricBuilder No convergence; Edm 0.00785812 is above tolerance 0.002
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder Machine accuracy limits further improvement
# W MnPosDef non-positive diagonal element in covariance matrix[ 18 ] = -1.03982e-06
# W MnPosDef Added to diagonal of Error matrix a value 0.500002
# W VariableMetricBuilder Reached machine accuracy limit; Edm 0.000826848 is smaller than machine limit 0.02524 while 0.0002 was requested
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 4280
# 	total stat : 423457.65
#
# CovarianceResult
#
# 	backend    : minuit
# 	method     : hesse
# 	success    : True
# 	message    : Hesse terminated successfully.
#
#    * Analysis of the source 8... complete!

# %%
print(stacked.models)
# Out:
# DatasetModels
#
# Component 0: FoVBackgroundModel
#
#   Name                      : my-dataset-bkg
#   Datasets names            : ['my-dataset']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      0.979   +/-    0.00
#     tilt                  (frozen):      0.000
#     reference             (frozen):      1.000       TeV
#
# Component 1: SkyModel
#
#   Name                      : src_0
#   Datasets names            : None
#   Spectral model type       : PowerLawSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                         :      1.995   +/-    0.07
#     amplitude                     :   5.29e-13   +/- 6.0e-14 1 / (TeV s cm2)
#     reference             (frozen):      1.000       TeV
#     lon_0                 (frozen):    254.715       deg
#     lat_0                 (frozen):    -47.456       deg
#     sigma                         :      0.046   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 2: SkyModel
#
#   Name                      : src_1
#   Datasets names            : None
#   Spectral model type       : PowerLawSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                         :      3.223   +/-    0.11
#     amplitude                     :   7.02e-13   +/- 6.5e-14 1 / (TeV s cm2)
#     reference             (frozen):      1.000       TeV
#     lon_0                 (frozen):    258.844       deg
#     lat_0                 (frozen):    -43.905       deg
#     sigma                         :      0.012   +/-    0.01 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 3: SkyModel
#
#   Name                      : src_2
#   Datasets names            : None
#   Spectral model type       : PowerLawSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                         :     -0.142   +/-    0.07
#     amplitude                     :   5.98e-15   +/- 1.3e-15 1 / (TeV s cm2)
#     reference             (frozen):      1.000       TeV
#     lon_0                 (frozen):    256.296       deg
#     lat_0                 (frozen):    -46.207       deg
#     sigma                         :      0.102   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 4: SkyModel
#
#   Name                      : src_3
#   Datasets names            : None
#   Spectral model type       : PowerLawSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                         :      1.833   +/-    0.06
#     amplitude                     :   1.31e-12   +/- 2.3e-13 1 / (TeV s cm2)
#     reference             (frozen):      1.000       TeV
#     lon_0                 (frozen):    256.980       deg
#     lat_0                 (frozen):    -44.217       deg
#     sigma                         :      0.295   +/-    0.02 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 5: SkyModel
#
#   Name                      : src_4
#   Datasets names            : None
#   Spectral model type       : PowerLawSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                         :      2.035   +/-    0.05
#     amplitude                     :   2.51e-12   +/- 2.7e-13 1 / (TeV s cm2)
#     reference             (frozen):      1.000       TeV
#     lon_0                 (frozen):    257.121       deg
#     lat_0                 (frozen):    -44.417       deg
#     sigma                         :      0.286   +/-    0.01 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 6: SkyModel
#
#   Name                      : src_5
#   Datasets names            : None
#   Spectral model type       : PowerLawSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                         :      2.795   +/-    0.29
#     amplitude                     :   9.06e-14   +/- 1.7e-14 1 / (TeV s cm2)
#     reference             (frozen):      1.000       TeV
#     lon_0                 (frozen):    256.766       deg
#     lat_0                 (frozen):    -44.490       deg
#     sigma                         :      0.000   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 7: SkyModel
#
#   Name                      : src_6
#   Datasets names            : None
#   Spectral model type       : PowerLawSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                         :      2.809   +/-    0.14
#     amplitude                     :   2.23e-13   +/- 3.1e-14 1 / (TeV s cm2)
#     reference             (frozen):      1.000       TeV
#     lon_0                 (frozen):    256.154       deg
#     lat_0                 (frozen):    -45.956       deg
#     sigma                         :      0.001   +/-    0.00 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 8: SkyModel
#
#   Name                      : src_7
#   Datasets names            : None
#   Spectral model type       : PowerLawSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                         :      0.561   +/-    0.12
#     amplitude                     :  -6.45e-15   +/- 2.4e-15 1 / (TeV s cm2)
#     reference             (frozen):      1.000       TeV
#     lon_0                 (frozen):    254.730       deg
#     lat_0                 (frozen):    -45.896       deg
#     sigma                         :      0.398   +/-    0.06 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg

# %%
estimator = ExcessMapEstimator(
    correlation_radius="0.1 deg",
    selection_optional=[],
    energy_edges=[0.3, 1, 5, 10, 20, 100] * u.TeV,
)

result = estimator.run(stacked)
result["sqrt_ts"].plot_grid(
    figsize=(12, 12), cmap="coolwarm", add_cbar=True, vmin=-5, vmax=5, ncols=2
)
plt.show()

# %%
ra, dec, index, amplitude, sigma = [], [], [], [], []
for mod in stacked.models[1:]:
    ra.append(mod.spatial_model.lon_0.value) 
    dec.append(mod.spatial_model.lat_0.value) 
    index.append(mod.spectral_model.index.value) 
    amplitude.append(mod.spectral_model.amplitude.value) 
    sigma.append(mod.spatial_model.sigma.value)

# %%
catalogue = Table()

catalogue["Src"] = np.arange(len(ra)) + 1
catalogue["Ra"] = ra * u.deg
catalogue["Dec"] = dec * u.deg
catalogue["Amplitude"] = amplitude  * u.cm**-2 * u.s**-1 * u.TeV**-1
#catalogue["Amplitude_err"]
catalogue[r"$\Gamma$"] = index
#catalogue["Index_err"]
catalogue[r"$\sigma$"] = sigma * u.deg
catalogue["Sqrt TS"] = sources["value"]
#catalogue["sigma_err"]

print(catalogue)
# Out:
# Src         Ra                 Dec         ...       $\Gamma$              $\sigma$       Sqrt TS
#            deg                 deg         ...                               deg
# --- ------------------ ------------------- ... -------------------- --------------------- -------
#   1   254.715469322397  -47.45615139697405 ...   1.9908491246919366   0.04637819886893639  14.119
#   2  258.8439684898101  -43.90530489696395 ...    3.215259423351967  0.012279852612804629  13.657
#   3  256.2963711327568  -46.20684552804714 ... -0.08640540991639462   0.10187654698693321  10.593
#   4 256.98007714301366  -44.21748153680484 ...   1.7671675229751769    0.3140465036564066   9.193
#   5  257.1211076671904 -44.417014599639955 ...   1.9907116862817982     0.291694344233289  9.0537
#   6 256.76562967473507 -44.489759694603784 ...  -0.5525697095906249   0.33325075854169317  8.0141
#   7  256.1457464123502  -45.96418601261675 ...    2.759665544386215 0.0005825648035501711  7.6608
#   8 254.72962205790378  -45.89608812461792 ...    3.694363288077561 0.0009451013317348614  6.3833

# %%
catalog = SourceCatalogGammaCat()

i = 4
src_coord = SkyCoord(catalogue["Ra"][i], catalogue["Dec"][i], frame="icrs", unit="deg")
idx = np.argmin(src_coord.separation(catalog.positions).degree)
catalog[idx]
# Out:
# <pre>
# *** Basic info ***
#
# Catalog row index (zero-based): 92
# Common name: HESS J1708-443
# Gamma names: HESS J1708-443
# Fermi names: --
# Other names: PSR B1706-44,G343.1-2.3
# Location: gal
# Class: pwn
#
# TeVCat ID: 191
# TeVCat 2 ID: jrf7QE
# TeVCat name: TeV J1708-443
#
# TGeVCat ID: 94
# TGeVCat name: TeV J1708-4420
#
# Discoverer: hess
# Discovery date: 2009-07
# Seen by: hess,cangaroo
# Reference: 2011A&amp;A...528A.143H
#
# *** Position info ***
#
# SIMBAD:
# RA: 257.000 deg
# DEC: -44.300 deg
# GLON: 343.065 deg
# GLAT: -2.330 deg
#
# Measurement:
# RA: 257.046 deg
# DEC: -44.333 deg
# GLON: 343.058 deg
# GLAT: -2.376 deg
# Position error: 0.069 deg
#
# *** Morphology info ***
#
# Morphology model type: gauss
# Sigma: 0.290 deg
# Sigma error: 0.040 deg
# Sigma2: 0.000 deg
# Sigma2 error: 0.000 deg
# Position angle: 0.000 deg
# Position angle error: 0.000 deg
# Position angle frame: --
#
# *** Spectral info ***
#
# Significance: 7.000
# Livetime: 15.000 h
#
# Spectrum type: pl
# norm: 4.2e-12 1 / (TeV s cm2) +- 8e-13 1 / (TeV s cm2) (stat) +- 1e-12 1 / (TeV s cm2) (sys) cm-2 s-1 TeV-1
# index: 2.0 +- 0.1 (stat) +- 0.2 (sys)
# reference: 1.0 TeV
#
# Energy range: (0.56, 0.0) TeV
# theta: 0.71 deg
#
#
# Derived fluxes:
# Spectral model norm (1 TeV): 4.2e-12 1 / (TeV s cm2) +- 8e-13 1 / (TeV s cm2) (stat) cm-2 s-1 TeV-1
# Integrated flux (&gt;1 TeV): 4.2e-12 +- 9.04e-13 (stat) cm-2 s-1
# Integrated flux (&gt;1 TeV): 20.246 +- 4.356 (% Crab)
# Integrated flux (1-10 TeV): 1.55e-11 +- 2.95e-12 (stat) erg cm-2 s-1
#
# *** Spectral points ***
#
# SED reference ID: 2011A&amp;A...528A.143H
# Number of spectral points: 5
# Number of upper limits: 0
#
# e_ref        dnde         dnde_errn       dnde_errp
#  TeV   1 / (TeV s cm2) 1 / (TeV s cm2) 1 / (TeV s cm2)
# ------ --------------- --------------- ---------------
#  0.908       4.130e-12       1.580e-12       1.580e-12
#  1.930       1.250e-12       2.340e-13       2.350e-13
#  4.140       2.320e-13       5.710e-14       5.730e-14
#  8.900       7.820e-14       1.460e-14       1.480e-14
# 19.100       8.110e-15       4.240e-15       4.300e-15
# </pre>
